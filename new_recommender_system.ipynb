# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import wordnet
from surprise import Reader, Dataset, SVD, accuracy
from surprise.model_selection import train_test_split

# %%
# Loading the movies metadata Dataset

df = pd.read_csv('dataset/movies_metadata.csv', low_memory=False)
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
# Here we extract the realse Year of the movie from the entire DateTime , and if not there makes it NaN

df['year'] = pd.to_datetime(df['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
df['year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45461     NaT
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: year, Length: 45466, dtype: object

# %%
# Checking out what kind of Genres we have and filling out the empty genres with empty list ( It was Json previouesly )
df['genres'] = df['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
df['genres']
# Out:
# 0         [Animation, Comedy, Family]
# 1        [Adventure, Fantasy, Family]
# 2                   [Romance, Comedy]
# 3            [Comedy, Drama, Romance]
# 4                            [Comedy]
#                      ...
# 45461                 [Drama, Family]
# 45462                         [Drama]
# 45463       [Action, Drama, Thriller]
# 45464                              []
# 45465                              []
# Name: genres, Length: 45466, dtype: object

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                              genres                              homepage  \
# 0       [Animation, Comedy, Family]  http://toystory.disney.com/toy-story
# 1      [Adventure, Fantasy, Family]                                   NaN
# 2                 [Romance, Comedy]                                   NaN
# 3          [Comedy, Drama, Romance]                                   NaN
# 4                          [Comedy]                                   NaN
# ...                             ...                                   ...
# 45461               [Drama, Family]  http://www.imdb.com/title/tt6209470/
# 45462                       [Drama]                                   NaN
# 45463     [Action, Drama, Thriller]                                   NaN
# 45464                            []                                   NaN
# 45465                            []                                   NaN
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 45461  439050  tt6209470                fa                      رگ خواب
# 45462  111109  tt2028550                tl          Siglo ng Pagluluwal
# 45463   67758  tt0303758                en                     Betrayal
# 45464  227506  tt0008536                en          Satana likuyushchiy
# 45465  461257  tt6980792                en                     Queerama
#
#                                                 overview  ...      revenue  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1      When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2      A family wedding reignites the ancient feud be...  ...          0.0
# 3      Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 4      Just when George Banks has recovered from his ...  ...   76578911.0
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          0.0
# 45462  An artist struggles to finish his work while a...  ...          0.0
# 45463  When one of her hits goes wrong, a professiona...  ...          0.0
# 45464  In a small town live two brothers, one a minis...  ...          0.0
# 45465  50 years after decriminalisation of homosexual...  ...          0.0
#
#       runtime                                   spoken_languages    status  \
# 0        81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2       101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3       127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4       106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...       ...                                                ...       ...
# 45461    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462   360.0                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464    87.0                                                 []  Released
# 45465    75.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video vote_average vote_count  year
# 0                        Toy Story  False          7.7     5415.0  1995
# 1                          Jumanji  False          6.9     2413.0  1995
# 2                 Grumpier Old Men  False          6.5       92.0  1995
# 3                Waiting to Exhale  False          6.1       34.0  1995
# 4      Father of the Bride Part II  False          5.7      173.0  1995
# ...                            ...    ...          ...        ...   ...
# 45461                       Subdue  False          4.0        1.0   NaT
# 45462          Century of Birthing  False          9.0        3.0  2011
# 45463                     Betrayal  False          3.8        6.0  2003
# 45464             Satan Triumphant  False          0.0        0.0  1917
# 45465                     Queerama  False          0.0        0.0  2017
#
# [45466 rows x 25 columns]

# %%
# Getting the mean of the vote_averge and converting the vote_counts to int so it is easier to deal with 

vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = df[df['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()
C
# Out:
# 5.244896612406511

# %%
# Getting the 0.85 quantile of the vote counts

m = vote_counts.quantile(0.85)
m
# Out:
# 82.0

# %%
# We select the movies which has the vote count of atleast the 0.95 quantile ( which is 434 ) and if it is below that we consider it not qualified
qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres']]

# We convert the type of the vote_count and vote_averge to int ( since we did that above so we will need to do that again to the new part of the dataset we made )
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')
qualified.shape
# Out:
# (6832, 6)

# %%
# Gives weights to each movie depending on thier vote_count and thier vote_averge using some Formula 

def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']                
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Applying the weight_rating function to the qualifted Movies

qualified['wr'] = qualified.apply(weighted_rating, axis=1)

# %%
# Printing the qualifed movies to check out the wr for them

qualified
# Out:
#                                                 title  year  vote_count  \
# 0                                           Toy Story  1995        5415
# 1                                             Jumanji  1995        2413
# 2                                    Grumpier Old Men  1995          92
# 4                         Father of the Bride Part II  1995         173
# 5                                                Heat  1995        1886
# ...                                               ...   ...         ...
# 45268  Good Guys Go to Heaven, Bad Guys Go to Pattaya  2016         153
# 45339                                  With Open Arms  2017          94
# 45343                      The Visitors: Bastille Day  2016         167
# 45437                                  In a Heartbeat  2017         146
# 45441                                     Cadet Kelly  2002         145
#
#        vote_average popularity                                genres        wr
# 0                 7  21.946943           [Animation, Comedy, Family]  6.973819
# 1                 6  17.015539          [Adventure, Fantasy, Family]  5.975183
# 2                 6    11.7129                     [Romance, Comedy]  5.644147
# 4                 5   8.387519                              [Comedy]  5.078751
# 5                 7  17.924927      [Action, Crime, Drama, Thriller]  6.926871
# ...             ...        ...                                   ...       ...
# 45268             5   5.613875                              [Comedy]  5.085453
# 45339             5   7.250495                              [Comedy]  5.114100
# 45343             4    7.29492                              [Comedy]  4.409966
# 45437             8   20.82178  [Family, Animation, Romance, Comedy]  7.009129
# 45441             5   4.392389                              [Comedy]  5.088465
#
# [6832 rows x 7 columns]

# %%
# Sorting the movies upon thier wr 

qualified = qualified.sort_values('wr', ascending=False)

# %% [markdown]
# Top 10 Movies

# %%
# The top 10 movies with highest wr

qualified.head(10)
# Out:
#                                                    title  year  vote_count  \
# 10309                        Dilwale Dulhania Le Jayenge  1995         661
# 15480                                          Inception  2010       14075
# 12481                                    The Dark Knight  2008       12269
# 22879                                       Interstellar  2014       11187
# 2843                                          Fight Club  1999        9678
# 4863   The Lord of the Rings: The Fellowship of the Ring  2001        8892
# 292                                         Pulp Fiction  1994        8670
# 314                             The Shawshank Redemption  1994        8358
# 7000       The Lord of the Rings: The Return of the King  2003        8226
# 351                                         Forrest Gump  1994        8147
#
#        vote_average  popularity  \
# 10309             9   34.457024
# 15480             8   29.108149
# 12481             8  123.167259
# 22879             8   32.213481
# 2843              8   63.869599
# 4863              8   32.070725
# 292               8  140.950236
# 314               8   51.645403
# 7000              8   29.324358
# 351               8   48.307194
#
#                                                   genres        wr
# 10309                           [Comedy, Drama, Romance]  8.585574
# 15480  [Action, Thriller, Science Fiction, Mystery, A...  7.984042
# 12481                   [Drama, Action, Crime, Thriller]  7.981708
# 22879                [Adventure, Drama, Science Fiction]  7.979952
# 2843                                             [Drama]  7.976853
# 4863                        [Adventure, Fantasy, Action]  7.974825
# 292                                    [Thriller, Crime]  7.974187
# 314                                       [Drama, Crime]  7.973232
# 7000                        [Adventure, Fantasy, Action]  7.972807
# 351                             [Comedy, Drama, Romance]  7.972546

# %%
# Instead of having each movie having one row that has all genres we made it into mutliple rows so it is more friendly to deal with and then he droped the genres ( the one that has all o them in one row )

s = df.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1, drop=True)
s.name= 'genre'
gen_df = df.drop('genres', axis=1).join(s)

# %%
# Building a simple Recommender which simply suggests the best movies of each genre you chose

def build_chart(genre, percentile=0.85):
    df = gen_df[gen_df['genre'] == genre]
    vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
    m = vote_counts.quantile(percentile)
    
    qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity']]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    
    qualified['wr'] = qualified.apply(weighted_rating , axis = 1)
    qualified = qualified.sort_values('wr', ascending=False).head(250)
    
    return qualified

# %% [markdown]
# # Top 10 movies of the genre you choose

# %%
build_chart('Romance')
# Out:
#                              title  year  vote_count  vote_average popularity  \
# 10309  Dilwale Dulhania Le Jayenge  1995         661             9  34.457024
# 351                   Forrest Gump  1994        8147             8  48.307194
# 876                        Vertigo  1958        1162             8   18.20822
# 40251                   Your Name.  2016        1030             8  34.461252
# 883               Some Like It Hot  1959         835             8  11.845107
# ...                            ...   ...         ...           ...        ...
# 7582        How to Steal a Million  1966         133             7  12.389626
# 6912          Beauty and the Beast  1946         133             7   4.798852
# 24888              Remember Sunday  2013         131             7  11.190606
# 2801                     Body Heat  1981         128             7   5.991482
# 11837  I'm a Cyborg, But That's OK  2006         126             7   4.369975
#
#              wr
# 10309  8.585574
# 351    7.972546
# 876    7.818394
# 40251  7.796836
# 883    7.753633
# ...         ...
# 7582   6.330612
# 6912   6.330612
# 24888  6.324326
# 2801   6.314674
# 11837  6.308084
#
# [250 rows x 6 columns]

# %%
# Loading the links Dataset

links = pd.read_csv('dataset/links_small.csv')

# %%
# Filtering out rows where tmdbId is (null) and converting the tmdbId column to integers

links = links[links['tmdbId'].notnull()]['tmdbId'].astype('int')

# %%
# Detect non numeric values in the 'budget' column
numeric_budgets = pd.to_numeric(df['budget'], errors='coerce')
non_numeric_budgets = df[numeric_budgets.isna()]

# Detect non numeric values in the id column
numeric_ids = pd.to_numeric(df['id'], errors='coerce')
non_numeric_ids = df[numeric_ids.isna()]

# Display rows with issues
print(non_numeric_budgets)
print(non_numeric_ids)
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [Carousel Productions, Vision View Entertainme...
# 29503  [Aniplex, GoHands, BROSTA TV, Mardock Scramble...
# 35587  [Odyssey Media, Pulser Productions, Rogue Stat...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... revenue runtime spoken_languages status tagline  title  video  \
# 19730  ...     NaN     NaN              NaN    NaN     NaN    NaN    NaN
# 29503  ...     NaN     NaN              NaN    NaN     NaN    NaN    NaN
# 35587  ...     NaN     NaN              NaN    NaN     NaN    NaN    NaN
#
#       vote_average vote_count year
# 19730          NaN        NaN  NaT
# 29503          NaN        NaN  NaT
# 35587          NaN        NaN  NaT
#
# [3 rows x 25 columns]
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [Carousel Productions, Vision View Entertainme...
# 29503  [Aniplex, GoHands, BROSTA TV, Mardock Scramble...
# 35587  [Odyssey Media, Pulser Productions, Rogue Stat...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... revenue runtime spoken_languages status tagline  title  video  \
# 19730  ...     NaN     NaN              NaN    NaN     NaN    NaN    NaN
# 29503  ...     NaN     NaN              NaN    NaN     NaN    NaN    NaN
# 35587  ...     NaN     NaN              NaN    NaN     NaN    NaN    NaN
#
#       vote_average vote_count year
# 19730          NaN        NaN  NaT
# 29503          NaN        NaN  NaT
# 35587          NaN        NaN  NaT
#
# [3 rows x 25 columns]

# %%
df = df.drop([19730, 29503, 35587])

# %% [markdown]
# # Content Based Recommender

# %%
# Loading the credits and keywords Dataset

credits = pd.read_csv('dataset/credits.csv')
keywords = pd.read_csv('dataset/keywords.csv')

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...   31357
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...   11862
# ...                                                  ...     ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...  439050
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...  111109
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...   67758
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...  227506
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...  461257
#
# [45476 rows x 3 columns]

# %%
keywords
# Out:
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46416   67758                                                 []
# 46417  227506                                                 []
# 46418  461257                                                 []
#
# [46419 rows x 2 columns]

# %%
# Convert the id column in the keywords and credits to integers

keywords['id'] = keywords['id'].astype('int')
credits['id'] = credits['id'].astype('int')

# %%
# Convert the id column in the df to integers

df['id'] = df['id'].astype('int')

# %%
df.shape
# Out:
# (45463, 25)

# %%
# Merge the df with the credits and keywords on the id column

df = df.merge(credits, on='id')
df = df.merge(keywords, on='id')

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 46623  False                                                NaN         0
# 46624  False                                                NaN         0
# 46625  False                                                NaN         0
# 46626  False                                                NaN         0
# 46627  False                                                NaN         0
#
#                              genres                              homepage  \
# 0       [Animation, Comedy, Family]  http://toystory.disney.com/toy-story
# 1      [Adventure, Fantasy, Family]                                   NaN
# 2                 [Romance, Comedy]                                   NaN
# 3          [Comedy, Drama, Romance]                                   NaN
# 4                          [Comedy]                                   NaN
# ...                             ...                                   ...
# 46623               [Drama, Family]  http://www.imdb.com/title/tt6209470/
# 46624                       [Drama]                                   NaN
# 46625     [Action, Drama, Thriller]                                   NaN
# 46626                            []                                   NaN
# 46627                            []                                   NaN
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 46623  439050  tt6209470                fa                      رگ خواب
# 46624  111109  tt2028550                tl          Siglo ng Pagluluwal
# 46625   67758  tt0303758                en                     Betrayal
# 46626  227506  tt0008536                en          Satana likuyushchiy
# 46627  461257  tt6980792                en                     Queerama
#
#                                                 overview  ...    status  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  Released
# 1      When siblings Judy and Peter discover an encha...  ...  Released
# 2      A family wedding reignites the ancient feud be...  ...  Released
# 3      Cheated on, mistreated and stepped on, the wom...  ...  Released
# 4      Just when George Banks has recovered from his ...  ...  Released
# ...                                                  ...  ...       ...
# 46623        Rising and falling between a man and woman.  ...  Released
# 46624  An artist struggles to finish his work while a...  ...  Released
# 46625  When one of her hits goes wrong, a professiona...  ...  Released
# 46626  In a small town live two brothers, one a minis...  ...  Released
# 46627  50 years after decriminalisation of homosexual...  ...  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 46623         Rising and falling between a man and woman
# 46624                                                NaN
# 46625                             A deadly game of wits.
# 46626                                                NaN
# 46627                                                NaN
#
#                              title  video vote_average  vote_count  year  \
# 0                        Toy Story  False          7.7      5415.0  1995
# 1                          Jumanji  False          6.9      2413.0  1995
# 2                 Grumpier Old Men  False          6.5        92.0  1995
# 3                Waiting to Exhale  False          6.1        34.0  1995
# 4      Father of the Bride Part II  False          5.7       173.0  1995
# ...                            ...    ...          ...         ...   ...
# 46623                       Subdue  False          4.0         1.0   NaT
# 46624          Century of Birthing  False          9.0         3.0  2011
# 46625                     Betrayal  False          3.8         6.0  2003
# 46626             Satan Triumphant  False          0.0         0.0  1917
# 46627                     Queerama  False          0.0         0.0  2017
#
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 46623  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 46624  [{'cast_id': 1002, 'character': 'Sister Angela...
# 46625  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 46626  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 46627                                                 []
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 46623  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 46624  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 46625  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 46626  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 46627  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
#                                                 keywords
# 0      [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1      [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2      [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3      [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4      [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...                                                  ...
# 46623             [{'id': 10703, 'name': 'tragic love'}]
# 46624  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46625                                                 []
# 46626                                                 []
# 46627                                                 []
#
# [46628 rows x 28 columns]

# %%
df['cast'].dtype
# Out:
# dtype('O')

# %%
# Filter the df to include only rows where the id column's values are present in the links

sdf = df[df['id'].isin(links)]
sdf.shape
# Out:
# (9219, 28)

# %%
sdf
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45985  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...         0
# 46424  False                                                NaN         0
# 46425  False                                                NaN         0
# 46426  False                                                NaN         0
# 46427  False                                                NaN         0
#
#                                                   genres  \
# 0                            [Animation, Comedy, Family]
# 1                           [Adventure, Fantasy, Family]
# 2                                      [Romance, Comedy]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 45985  [Adventure, Fantasy, Animation, Science Fictio...
# 46424                                    [Comedy, Drama]
# 46425                                    [Comedy, Drama]
# 46426                                    [Comedy, Drama]
# 46427                                    [Comedy, Drama]
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                    NaN    8844  tt0113497
# 2                                                    NaN   15602  tt0113228
# 3                                                    NaN   31357  tt0114885
# 4                                                    NaN   11862  tt0113041
# ...                                                  ...     ...        ...
# 45985  http://www.pokemon.com/us/movies/movie-pokemon...   12600  tt0287635
# 46424                                                NaN  265189  tt2121382
# 46425                                                NaN  265189  tt2121382
# 46426                                                NaN  265189  tt2121382
# 46427                                                NaN  265189  tt2121382
#
#       original_language                  original_title  \
# 0                    en                       Toy Story
# 1                    en                         Jumanji
# 2                    en                Grumpier Old Men
# 3                    en               Waiting to Exhale
# 4                    en     Father of the Bride Part II
# ...                 ...                             ...
# 45985                ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 46424                sv                          Turist
# 46425                sv                          Turist
# 46426                sv                          Turist
# 46427                sv                          Turist
#
#                                                 overview  ...    status  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  Released
# 1      When siblings Judy and Peter discover an encha...  ...  Released
# 2      A family wedding reignites the ancient feud be...  ...  Released
# 3      Cheated on, mistreated and stepped on, the wom...  ...  Released
# 4      Just when George Banks has recovered from his ...  ...  Released
# ...                                                  ...  ...       ...
# 45985  All your favorite Pokémon characters are back,...  ...  Released
# 46424  While holidaying in the French Alps, a Swedish...  ...  Released
# 46425  While holidaying in the French Alps, a Swedish...  ...  Released
# 46426  While holidaying in the French Alps, a Swedish...  ...  Released
# 46427  While holidaying in the French Alps, a Swedish...  ...  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45985                                                NaN
# 46424                                                NaN
# 46425                                                NaN
# 46426                                                NaN
# 46427                                                NaN
#
#                                              title  video vote_average  \
# 0                                        Toy Story  False          7.7
# 1                                          Jumanji  False          6.9
# 2                                 Grumpier Old Men  False          6.5
# 3                                Waiting to Exhale  False          6.1
# 4                      Father of the Bride Part II  False          5.7
# ...                                            ...    ...          ...
# 45985  Pokémon 4Ever: Celebi - Voice of the Forest  False          5.7
# 46424                                Force Majeure  False          6.8
# 46425                                Force Majeure  False          6.8
# 46426                                Force Majeure  False          6.8
# 46427                                Force Majeure  False          6.8
#
#        vote_count  year                                               cast  \
# 0          5415.0  1995  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1          2413.0  1995  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2            92.0  1995  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3            34.0  1995  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4           173.0  1995  [{'cast_id': 1, 'character': 'George Banks', '...
# ...           ...   ...                                                ...
# 45985        82.0  2001  [{'cast_id': 1, 'character': 'Ash Ketchum (voi...
# 46424       255.0  2014  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 46425       255.0  2014  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 46426       255.0  2014  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 46427       255.0  2014  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45985  [{'credit_id': '52fe45049251416c75048e35', 'de...
# 46424  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46425  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46426  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46427  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
#
#                                                 keywords
# 0      [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1      [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2      [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3      [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4      [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...                                                  ...
# 45985  [{'id': 9663, 'name': 'sequel'}, {'id': 11451,...
# 46424  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 46425  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 46426  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 46427  [{'id': 293, 'name': 'female nudity'}, {'id': ...
#
# [9219 rows x 28 columns]

# %%
# Convert the string representation of lists in the cast, crew and keywords column into actual lists
sdf.loc[:, 'cast'] = sdf['cast'].apply(literal_eval)
sdf.loc[:, 'crew'] = sdf['crew'].apply(literal_eval)
sdf.loc[:, 'keywords'] = sdf['keywords'].apply(literal_eval)

# Create a new columns for cast_size and crew_size thats contains the number of elements in the cast and crew list for each row
sdf.loc[:,'cast_size'] = sdf['cast'].apply(lambda x: len(x))
sdf.loc[:,'crew_size'] = sdf['crew'].apply(lambda x: len(x))
# Out:
# C:\Users\medoo\AppData\Local\Temp\ipykernel_13208\717964689.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdf.loc[:,'cast_size'] = sdf['cast'].apply(lambda x: len(x))
# C:\Users\medoo\AppData\Local\Temp\ipykernel_13208\717964689.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdf.loc[:,'crew_size'] = sdf['crew'].apply(lambda x: len(x))

# %%
sdf
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45985  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...         0
# 46424  False                                                NaN         0
# 46425  False                                                NaN         0
# 46426  False                                                NaN         0
# 46427  False                                                NaN         0
#
#                                                   genres  \
# 0                            [Animation, Comedy, Family]
# 1                           [Adventure, Fantasy, Family]
# 2                                      [Romance, Comedy]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 45985  [Adventure, Fantasy, Animation, Science Fictio...
# 46424                                    [Comedy, Drama]
# 46425                                    [Comedy, Drama]
# 46426                                    [Comedy, Drama]
# 46427                                    [Comedy, Drama]
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                    NaN    8844  tt0113497
# 2                                                    NaN   15602  tt0113228
# 3                                                    NaN   31357  tt0114885
# 4                                                    NaN   11862  tt0113041
# ...                                                  ...     ...        ...
# 45985  http://www.pokemon.com/us/movies/movie-pokemon...   12600  tt0287635
# 46424                                                NaN  265189  tt2121382
# 46425                                                NaN  265189  tt2121382
# 46426                                                NaN  265189  tt2121382
# 46427                                                NaN  265189  tt2121382
#
#       original_language                  original_title  \
# 0                    en                       Toy Story
# 1                    en                         Jumanji
# 2                    en                Grumpier Old Men
# 3                    en               Waiting to Exhale
# 4                    en     Father of the Bride Part II
# ...                 ...                             ...
# 45985                ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 46424                sv                          Turist
# 46425                sv                          Turist
# 46426                sv                          Turist
# 46427                sv                          Turist
#
#                                                 overview  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...
# 1      When siblings Judy and Peter discover an encha...  ...
# 2      A family wedding reignites the ancient feud be...  ...
# 3      Cheated on, mistreated and stepped on, the wom...  ...
# 4      Just when George Banks has recovered from his ...  ...
# ...                                                  ...  ...
# 45985  All your favorite Pokémon characters are back,...  ...
# 46424  While holidaying in the French Alps, a Swedish...  ...
# 46425  While holidaying in the French Alps, a Swedish...  ...
# 46426  While holidaying in the French Alps, a Swedish...  ...
# 46427  While holidaying in the French Alps, a Swedish...  ...
#
#                                              title  video vote_average  \
# 0                                        Toy Story  False          7.7
# 1                                          Jumanji  False          6.9
# 2                                 Grumpier Old Men  False          6.5
# 3                                Waiting to Exhale  False          6.1
# 4                      Father of the Bride Part II  False          5.7
# ...                                            ...    ...          ...
# 45985  Pokémon 4Ever: Celebi - Voice of the Forest  False          5.7
# 46424                                Force Majeure  False          6.8
# 46425                                Force Majeure  False          6.8
# 46426                                Force Majeure  False          6.8
# 46427                                Force Majeure  False          6.8
#
#       vote_count  year                                               cast  \
# 0         5415.0  1995  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1         2413.0  1995  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2           92.0  1995  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3           34.0  1995  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4          173.0  1995  [{'cast_id': 1, 'character': 'George Banks', '...
# ...          ...   ...                                                ...
# 45985       82.0  2001  [{'cast_id': 1, 'character': 'Ash Ketchum (voi...
# 46424      255.0  2014  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 46425      255.0  2014  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 46426      255.0  2014  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 46427      255.0  2014  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45985  [{'credit_id': '52fe45049251416c75048e35', 'de...
# 46424  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46425  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46426  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46427  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
#
#                                                 keywords cast_size crew_size
# 0      [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...        13       106
# 1      [{'id': 10090, 'name': 'board game'}, {'id': 1...        26        16
# 2      [{'id': 1495, 'name': 'fishing'}, {'id': 12392...         7         4
# 3      [{'id': 818, 'name': 'based on novel'}, {'id':...        10        10
# 4      [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...        12         7
# ...                                                  ...       ...       ...
# 45985  [{'id': 9663, 'name': 'sequel'}, {'id': 11451,...         4        17
# 46424  [{'id': 293, 'name': 'female nudity'}, {'id': ...         9        15
# 46425  [{'id': 293, 'name': 'female nudity'}, {'id': ...         9        15
# 46426  [{'id': 293, 'name': 'female nudity'}, {'id': ...         9        15
# 46427  [{'id': 293, 'name': 'female nudity'}, {'id': ...         9        15
#
# [9219 rows x 30 columns]

# %%
# Create a function to extract the director name

def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
# Create a new column director that contains the name of the director for each movie

sdf['director'] = sdf['crew'].apply(get_director)
# Out:
# C:\Users\medoo\AppData\Local\Temp\ipykernel_13208\516768907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdf['director'] = sdf['crew'].apply(get_director)

# %%
# Convert the cast column so that it contains only the names of the cast members
sdf.loc[:,'cast'] = sdf['cast'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# Trim the cast list to include only the first three cast members
sdf.loc[:,'cast'] = sdf['cast'].apply(lambda x: x[:3] if len(x) >=3 else x)

# Convert each name in the cast column to lowercase and remove any spaces
sdf.loc[:,'cast'] = sdf['cast'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])

# %%
# Convert the keywords column so that it contains only the names of the keywords

sdf.loc[:,'keywords'] = sdf['keywords'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
# Convert the director column to string type, then converts the name to lowercase and removes any spaces
sdf.loc[:,'director'] = sdf['director'].astype('str').apply(lambda x: str.lower(x.replace(" ", "")))

# Mention Director 3 times to give it more weight relative to the entire cast.
sdf.loc[:,'director'] = sdf['director'].apply(lambda x: [x, x, x])

# %%
sdf
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45985  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...         0
# 46424  False                                                NaN         0
# 46425  False                                                NaN         0
# 46426  False                                                NaN         0
# 46427  False                                                NaN         0
#
#                                                   genres  \
# 0                            [Animation, Comedy, Family]
# 1                           [Adventure, Fantasy, Family]
# 2                                      [Romance, Comedy]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 45985  [Adventure, Fantasy, Animation, Science Fictio...
# 46424                                    [Comedy, Drama]
# 46425                                    [Comedy, Drama]
# 46426                                    [Comedy, Drama]
# 46427                                    [Comedy, Drama]
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                    NaN    8844  tt0113497
# 2                                                    NaN   15602  tt0113228
# 3                                                    NaN   31357  tt0114885
# 4                                                    NaN   11862  tt0113041
# ...                                                  ...     ...        ...
# 45985  http://www.pokemon.com/us/movies/movie-pokemon...   12600  tt0287635
# 46424                                                NaN  265189  tt2121382
# 46425                                                NaN  265189  tt2121382
# 46426                                                NaN  265189  tt2121382
# 46427                                                NaN  265189  tt2121382
#
#       original_language                  original_title  \
# 0                    en                       Toy Story
# 1                    en                         Jumanji
# 2                    en                Grumpier Old Men
# 3                    en               Waiting to Exhale
# 4                    en     Father of the Bride Part II
# ...                 ...                             ...
# 45985                ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 46424                sv                          Turist
# 46425                sv                          Turist
# 46426                sv                          Turist
# 46427                sv                          Turist
#
#                                                 overview  ...  video  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  False
# 1      When siblings Judy and Peter discover an encha...  ...  False
# 2      A family wedding reignites the ancient feud be...  ...  False
# 3      Cheated on, mistreated and stepped on, the wom...  ...  False
# 4      Just when George Banks has recovered from his ...  ...  False
# ...                                                  ...  ...    ...
# 45985  All your favorite Pokémon characters are back,...  ...  False
# 46424  While holidaying in the French Alps, a Swedish...  ...  False
# 46425  While holidaying in the French Alps, a Swedish...  ...  False
# 46426  While holidaying in the French Alps, a Swedish...  ...  False
# 46427  While holidaying in the French Alps, a Swedish...  ...  False
#
#       vote_average vote_count  year  \
# 0              7.7     5415.0  1995
# 1              6.9     2413.0  1995
# 2              6.5       92.0  1995
# 3              6.1       34.0  1995
# 4              5.7      173.0  1995
# ...            ...        ...   ...
# 45985          5.7       82.0  2001
# 46424          6.8      255.0  2014
# 46425          6.8      255.0  2014
# 46426          6.8      255.0  2014
# 46427          6.8      255.0  2014
#
#                                                     cast  \
# 0                       [tomhanks, timallen, donrickles]
# 1            [robinwilliams, jonathanhyde, kirstendunst]
# 2               [waltermatthau, jacklemmon, ann-margret]
# 3         [whitneyhouston, angelabassett, lorettadevine]
# 4                [stevemartin, dianekeaton, martinshort]
# ...                                                  ...
# 45985   [veronicataylor, rachaellillis, maddieblaustein]
# 46424  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46425  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46426  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 46427  [lisalovenkongsli, johannesbahkuhnke, clarawet...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45985  [{'credit_id': '52fe45049251416c75048e35', 'de...
# 46424  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46425  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46426  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 46427  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
#
#                                                 keywords cast_size crew_size  \
# 0      [jealousy, toy, boy, friendship, friends, riva...        13       106
# 1      [board game, disappearance, based on children'...        26        16
# 2      [fishing, best friend, duringcreditsstinger, o...         7         4
# 3      [based on novel, interracial relationship, sin...        10        10
# 4      [baby, midlife crisis, confidence, aging, daug...        12         7
# ...                                                  ...       ...       ...
# 45985                          [sequel, pokémon, celebi]         4        17
# 46424  [female nudity, dark comedy, family vacation, ...         9        15
# 46425  [female nudity, dark comedy, family vacation, ...         9        15
# 46426  [female nudity, dark comedy, family vacation, ...         9        15
# 46427  [female nudity, dark comedy, family vacation, ...         9        15
#
#                                                director
# 0            [johnlasseter, johnlasseter, johnlasseter]
# 1               [joejohnston, joejohnston, joejohnston]
# 2            [howarddeutch, howarddeutch, howarddeutch]
# 3      [forestwhitaker, forestwhitaker, forestwhitaker]
# 4            [charlesshyer, charlesshyer, charlesshyer]
# ...                                                 ...
# 45985  [kunihikoyuyama, kunihikoyuyama, kunihikoyuyama]
# 46424        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46425        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46426        [rubenöstlund, rubenöstlund, rubenöstlund]
# 46427        [rubenöstlund, rubenöstlund, rubenöstlund]
#
# [9219 rows x 31 columns]

# %%
# Extract and stack all keywords from the keywords column in 'sdf' into a single Series named keyword

s = sdf.apply(lambda x: pd.Series(x['keywords']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'keyword'

# %%
# Count the occurrences of each keyword in the Series s and display the top 5 most common keywords based on their counts

s = s.value_counts()
s[:5]
# Out:
# keyword
# independent film        610
# woman director          550
# murder                  399
# duringcreditsstinger    327
# based on novel          318
# Name: count, dtype: int64

# %%
# Filter the Series 's' to keep only keywords that occur more than once.

s = s[s > 1]

# %%
stemmer = SnowballStemmer('english')

# %%
# This function, filter_keywords, takes a list of keywords x as input and filters it to keep only those keywords that exist in the Series s

def filter_keywords(x):
    words = []
    for i in x:
        if i in s:
            words.append(i)
    return words

# %%
# Apply the 'filter_keywords' function to the keywords column to retain only those that are present in the Series s
sdf.loc[:,'keywords'] = sdf['keywords'].apply(filter_keywords)

# Apply stemming to each keyword in the keywords column using the stemmer object to transform each keyword into its root form
sdf.loc[:,'keywords'] = sdf['keywords'].apply(lambda x: [stemmer.stem(i) for i in x])

# Convert each keyword in the 'keywords' column to lowercase and remove any spaces.
sdf.loc[:,'keywords'] = sdf['keywords'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])

# %%
sdf = sdf.copy()

# Combine the keywords, cast, director, and genres columns into a single column soup.
sdf['soup'] = sdf['keywords'] + sdf['cast'] + sdf['director'] + sdf['genres']

# Convert the list of elements in soup to a single space-separated string
sdf['soup'] = sdf['soup'].apply(lambda x: ' '.join(x))

# %%
# Initialize CountVectorizer to convert text data into a matrix of token counts (unigrams and bigrams), ignoring English stop words
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0.0, stop_words='english')

# Fit the CountVectorizer to the soup column and transform it into a sparse matrix of word/token counts
count_matrix = count.fit_transform(sdf['soup'])

# %%
# Compute the cosine similarity between the rows of the count matrix

cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
cosine_sim
# Out:
# array([[1.        , 0.02441931, 0.02738955, ..., 0.02135407, 0.02135407,
#         0.02135407],
#        [0.02441931, 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.02738955, 0.        , 1.        , ..., 0.02514977, 0.02514977,
#         0.02514977],
#        ...,
#        [0.02135407, 0.        , 0.02514977, ..., 1.        , 1.        ,
#         1.        ],
#        [0.02135407, 0.        , 0.02514977, ..., 1.        , 1.        ,
#         1.        ],
#        [0.02135407, 0.        , 0.02514977, ..., 1.        , 1.        ,
#         1.        ]])

# %%
# Reset the index of the DataFrame, creating a new default integer index and moving the old index to a column
sdf = sdf.reset_index()

# Extract the title column from the DataFrame and store it as a separate variable for later use
titles = sdf['title']

# Create a Pandas Series with movie titles as the index and their corresponding DataFrame indices as the values
indices = pd.Series(sdf.index, index=sdf['title'])

# %%
indices
# Out:
# title
# Toy Story                                         0
# Jumanji                                           1
# Grumpier Old Men                                  2
# Waiting to Exhale                                 3
# Father of the Bride Part II                       4
#                                                ...
# Pokémon 4Ever: Celebi - Voice of the Forest    9214
# Force Majeure                                  9215
# Force Majeure                                  9216
# Force Majeure                                  9217
# Force Majeure                                  9218
# Length: 9219, dtype: int64

# %%
sdf
# Out:
#       index  adult                              belongs_to_collection  \
# 0         0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1         1  False                                                NaN
# 2         2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3         3  False                                                NaN
# 4         4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...     ...    ...                                                ...
# 9214  45985  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...
# 9215  46424  False                                                NaN
# 9216  46425  False                                                NaN
# 9217  46426  False                                                NaN
# 9218  46427  False                                                NaN
#
#         budget                                             genres  \
# 0     30000000                        [Animation, Comedy, Family]
# 1     65000000                       [Adventure, Fantasy, Family]
# 2            0                                  [Romance, Comedy]
# 3     16000000                           [Comedy, Drama, Romance]
# 4            0                                           [Comedy]
# ...        ...                                                ...
# 9214         0  [Adventure, Fantasy, Animation, Science Fictio...
# 9215         0                                    [Comedy, Drama]
# 9216         0                                    [Comedy, Drama]
# 9217         0                                    [Comedy, Drama]
# 9218         0                                    [Comedy, Drama]
#
#                                                homepage      id    imdb_id  \
# 0                  http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                   NaN    8844  tt0113497
# 2                                                   NaN   15602  tt0113228
# 3                                                   NaN   31357  tt0114885
# 4                                                   NaN   11862  tt0113041
# ...                                                 ...     ...        ...
# 9214  http://www.pokemon.com/us/movies/movie-pokemon...   12600  tt0287635
# 9215                                                NaN  265189  tt2121382
# 9216                                                NaN  265189  tt2121382
# 9217                                                NaN  265189  tt2121382
# 9218                                                NaN  265189  tt2121382
#
#      original_language                  original_title  ... vote_average  \
# 0                   en                       Toy Story  ...          7.7
# 1                   en                         Jumanji  ...          6.9
# 2                   en                Grumpier Old Men  ...          6.5
# 3                   en               Waiting to Exhale  ...          6.1
# 4                   en     Father of the Bride Part II  ...          5.7
# ...                ...                             ...  ...          ...
# 9214                ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）  ...          5.7
# 9215                sv                          Turist  ...          6.8
# 9216                sv                          Turist  ...          6.8
# 9217                sv                          Turist  ...          6.8
# 9218                sv                          Turist  ...          6.8
#
#      vote_count  year                                               cast  \
# 0        5415.0  1995                   [tomhanks, timallen, donrickles]
# 1        2413.0  1995        [robinwilliams, jonathanhyde, kirstendunst]
# 2          92.0  1995           [waltermatthau, jacklemmon, ann-margret]
# 3          34.0  1995     [whitneyhouston, angelabassett, lorettadevine]
# 4         173.0  1995            [stevemartin, dianekeaton, martinshort]
# ...         ...   ...                                                ...
# 9214       82.0  2001   [veronicataylor, rachaellillis, maddieblaustein]
# 9215      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 9216      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 9217      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
# 9218      255.0  2014  [lisalovenkongsli, johannesbahkuhnke, clarawet...
#
#                                                    crew  \
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1     [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2     [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3     [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4     [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                 ...
# 9214  [{'credit_id': '52fe45049251416c75048e35', 'de...
# 9215  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 9216  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 9217  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
# 9218  [{'credit_id': '534fd1a80e0a267eb6000e32', 'de...
#
#                                                keywords  cast_size  crew_size  \
# 0     [jealousi, toy, boy, friendship, friend, rival...         13        106
# 1     [boardgam, disappear, basedonchildren'sbook, n...         26         16
# 2                [fish, bestfriend, duringcreditssting]          7          4
# 3     [basedonnovel, interracialrelationship, single...         10         10
# 4     [babi, midlifecrisi, confid, age, daughter, mo...         12          7
# ...                                                 ...        ...        ...
# 9214                          [sequel, pokémon, celebi]          4         17
# 9215  [femalenud, darkcomedi, familyvac, avalanch, r...          9         15
# 9216  [femalenud, darkcomedi, familyvac, avalanch, r...          9         15
# 9217  [femalenud, darkcomedi, familyvac, avalanch, r...          9         15
# 9218  [femalenud, darkcomedi, familyvac, avalanch, r...          9         15
#
#                                               director  \
# 0           [johnlasseter, johnlasseter, johnlasseter]
# 1              [joejohnston, joejohnston, joejohnston]
# 2           [howarddeutch, howarddeutch, howarddeutch]
# 3     [forestwhitaker, forestwhitaker, forestwhitaker]
# 4           [charlesshyer, charlesshyer, charlesshyer]
# ...                                                ...
# 9214  [kunihikoyuyama, kunihikoyuyama, kunihikoyuyama]
# 9215        [rubenöstlund, rubenöstlund, rubenöstlund]
# 9216        [rubenöstlund, rubenöstlund, rubenöstlund]
# 9217        [rubenöstlund, rubenöstlund, rubenöstlund]
# 9218        [rubenöstlund, rubenöstlund, rubenöstlund]
#
#                                                    soup
# 0     jealousi toy boy friendship friend rivalri boy...
# 1     boardgam disappear basedonchildren'sbook newho...
# 2     fish bestfriend duringcreditssting waltermatth...
# 3     basedonnovel interracialrelationship singlemot...
# 4     babi midlifecrisi confid age daughter motherda...
# ...                                                 ...
# 9214  sequel pokémon celebi veronicataylor rachaelli...
# 9215  femalenud darkcomedi familyvac avalanch runnin...
# 9216  femalenud darkcomedi familyvac avalanch runnin...
# 9217  femalenud darkcomedi familyvac avalanch runnin...
# 9218  femalenud darkcomedi familyvac avalanch runnin...
#
# [9219 rows x 33 columns]

# %%
def get_recommendations(title):
    
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    movies = sdf.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year']]
    
    vote_counts = movies[movies['vote_count'].notnull()]['vote_count'].astype('int')
    m = vote_counts.quantile(0.60)
    
    qualified = movies[(movies['vote_count'] >= m) & (movies['vote_count'].notnull()) & (movies['vote_average'].notnull())]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    qualified['wr'] = qualified.apply(weighted_rating, axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(10)
    return qualified

# %%
get_recommendations('The Dark Knight')
# Out:
# C:\Users\medoo\AppData\Local\Temp\ipykernel_13208\4286952062.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualified['vote_count'] = qualified['vote_count'].astype('int')
# C:\Users\medoo\AppData\Local\Temp\ipykernel_13208\4286952062.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualified['vote_average'] = qualified['vote_average'].astype('int')
# C:\Users\medoo\AppData\Local\Temp\ipykernel_13208\4286952062.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualified['wr'] = qualified.apply(weighted_rating, axis=1)
#                                    title  vote_count  vote_average  year  \
# 7608                           Inception       14075             8  2010
# 8573                        Interstellar       11187             8  2014
# 6587                        The Prestige        4510             8  2006
# 3373                             Memento        4168             8  2000
# 7991               The Dark Knight Rises        9263             7  2012
# 6186                       Batman Begins        7511             7  2005
# 1122                      Batman Returns        1706             6  1992
# 132                       Batman Forever        1529             5  1995
# 9004  Batman v Superman: Dawn of Justice        7189             5  2016
# 1252                      Batman & Robin        1447             4  1997
#
#             wr
# 7608  7.984042
# 8573  7.979952
# 6587  7.950802
# 3373  7.946843
# 7991  6.984599
# 6186  6.981046
# 1122  5.965370
# 132   5.012465
# 9004  5.002762
# 1252  4.066764

# %% [markdown]
# # Collaborative Filtering

# %%
# Loading the ratings Dataset

ratings = pd.read_csv('dataset/ratings_small.csv')
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %% [markdown]
# ### we used GANs to genrate new ratings ( with 1.1 ratio  to the training data using those ratings)

# %%
# Loading the Genrated ratings Dataset

ratings_gn = pd.read_csv('dataset/Genrated ratings Data.csv')
ratings_gn
# Out:
#         userId  movieId   timestamp    rating
# 0          510   133730   849588178  2.097580
# 1          510   148672   846457615  3.033221
# 2          513   146590   851162656  2.529508
# 3          510   132772   846242746  2.091977
# 4          514   146968   833662076  0.333745
# ...        ...      ...         ...       ...
# 182987     624   142536  1473962172  2.000000
# 182988     624   140725  1462187665  3.000000
# 182989     624   144714  1474972061  1.500000
# 182990     624   143257  1461356507  2.500000
# 182991     624   142997  1476465026  2.500000
#
# [182992 rows x 4 columns]

# %%
# Set the 'rating' values to 1 for all entries in 'ratings_gn' where the rating is less than 1
ratings_gn.loc[ratings_gn['rating'] < 1, 'rating'] = 1

# Set the 'rating' values to 5 for all entries in 'ratings_gn' where the rating is greater than 5.
ratings_gn.loc[ratings_gn['rating'] > 5, 'rating'] = 5

# %%
top_users = ratings_gn['userId'].value_counts().head(10)
plt.figure(figsize=(12, 5))
sns.barplot(x=top_users.index, y=top_users.values, hue=top_users.index, palette='viridis', dodge=False)
plt.title('Top 10 Users by Number of Reviews')
plt.xlabel('UserId')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45)
plt.show()

# %%
top_Movies = ratings_gn['movieId'].value_counts().head(10)

plt.figure(figsize=(12, 5))
sns.barplot(x=top_Movies.index, y=top_Movies.values, hue=top_Movies.index, palette='viridis')
plt.title('Top 10 Movies by Number of Reviews')
plt.xlabel('movieId')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45)
plt.show()

# %%
# Convert the timestamp column from Unix time to a datetime format, then extract the Year and Month from the converted timestamps

ratings_gn['timestamp'] = pd.to_datetime(ratings_gn['timestamp'], unit='s')
ratings_gn['Year'] = ratings_gn['timestamp'].dt.year
ratings_gn['Month'] = ratings_gn['timestamp'].dt.month

# %%
plt.figure(figsize=(12, 5))
ratings_gn.groupby(ratings_gn['timestamp'].dt.to_period('M')).size().plot(kind='line', linewidth =2.5, color='purple')
plt.title('Number of Reviews Over Time')
plt.xlabel('Time')
plt.ylabel('Number of Reviews')
plt.show()

# %%
# Load the ratings data into a Surprise Dataset format, split it into training and testing sets, and fit an SVD model to the training data.
reader = Reader(rating_scale=(1,5))
data = Dataset.load_from_df(ratings_gn[['userId', 'movieId', 'rating']], reader)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)
model = SVD(n_factors= 10, n_epochs= 50, lr_all= 0.002, reg_all= 0.1, random_state= 42)
model.fit(trainset)

# %%
# Generate predictions using the trained SVD model on the test set and calculate the root mean square error (RMSE) to evaluate accuracy.

predictions = model.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 1.1590
# 1.1590480801840863

# %%
# from surprise.model_selection import GridSearchCV
# param_grid = {
#     'n_factors': [10, 20, 50, 100],           # Number of latent factors
#     'n_epochs': [10, 20, 30, 50],             # Number of training epochs
#     'lr_all': [0.002, 0.005, 0.01],           # Learning rate for all parameters
#     'reg_all': [0.02, 0.1, 0.2],              # Regularization term
#     'random_state': [42]                      # Seed for random number generator
# }

# gs = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=5)

# gs.fit(data)

# print('Best RMSE:', gs.best_score['rmse'])

# print('Best parameters:', gs.best_params['rmse'])

# %% [markdown]
# Best RMSE: 1.1602767005988195
# Best parameters: {'n_factors': 10, 'n_epochs': 50, 'lr_all': 0.002, 'reg_all': 0.1, 'random_state': 42}

# %%
ratings[ratings['userId'] == 1]
# Out:
#     userId  movieId  rating   timestamp
# 0        1       31     2.5  1260759144
# 1        1     1029     3.0  1260759179
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 4        1     1172     4.0  1260759205
# 5        1     1263     2.0  1260759151
# 6        1     1287     2.0  1260759187
# 7        1     1293     2.0  1260759148
# 8        1     1339     3.5  1260759125
# 9        1     1343     2.0  1260759131
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203
# 12       1     1953     4.0  1260759191
# 13       1     2105     4.0  1260759139
# 14       1     2150     3.0  1260759194
# 15       1     2193     2.0  1260759198
# 16       1     2294     2.0  1260759108
# 17       1     2455     2.5  1260759113
# 18       1     2968     1.0  1260759200
# 19       1     3671     3.0  1260759117

# %%
model.predict(1, 302)
# Out:
# Prediction(uid=1, iid=302, r_ui=None, est=3.0260835076667685, details={'was_impossible': False})

# %%
# Convert the input x to an integer; if the conversion fails, return NaN.

def convert_int(x):
    try:
        return int(x)
    except:
        return np.nan

# %%
# Load a mapping of movie IDs from a CSV file, convert the 'tmdbId' to integers (replacing non-convertible values with NaN), 
id_map = pd.read_csv('dataset/links_small.csv')[['movieId', 'tmdbId']]
id_map['tmdbId'] = id_map['tmdbId'].apply(convert_int)

# rename columns for clarity, and merge with another DataFrame (sdf) on 'id' to create an index based on movie titles.
id_map.columns = ['movieId', 'id']
id_map = id_map.merge(sdf[['title', 'id']], on='id').set_index('title')

# %%
id_map
# Out:
#                                                     movieId        id
# title
# Toy Story                                                 1     862.0
# Jumanji                                                   2    8844.0
# Grumpier Old Men                                          3   15602.0
# Waiting to Exhale                                         4   31357.0
# Father of the Bride Part II                               5   11862.0
# ...                                                     ...       ...
# The Last Brickmaker in America                       161944  159550.0
# Rustom                                               162542  392572.0
# Mohenjo Daro                                         162672  402672.0
# Shin Godzilla                                        163056  315011.0
# The Beatles: Eight Days a Week - The Touring Years   163949  391698.0
#
# [9219 rows x 2 columns]

# %%
# Set the 'id' column as the index of the id_map DataFrame for easier access and lookup by 'id'.

indices_map = id_map.set_index('id')
indices_map
# Out:
#           movieId
# id
# 862.0           1
# 8844.0          2
# 15602.0         3
# 31357.0         4
# 11862.0         5
# ...           ...
# 159550.0   161944
# 392572.0   162542
# 402672.0   162672
# 315011.0   163056
# 391698.0   163949
#
# [9219 rows x 1 columns]

# %%
import joblib

# Save the CountVectorizer object
joblib.dump(count, 'model/count_vectorizer.pkl')

# Save the cosine similarity matrix
joblib.dump(cosine_sim, 'model/cosine_sim_matrix.pkl')

# Saving the model Weights 
joblib.dump(model, 'model/svd_recommender_model.pkl')

# Save the id_map and indices_map for later use
joblib.dump(id_map, 'model/id_map.pkl')
joblib.dump(indices_map, 'model/indices_map.pkl')
joblib.dump(indices, 'model/indices_series.pkl')
# Out:
# ['model/indices_series.pkl']

# %%
def hybrid_recommendations(userId, title):
    title = str(title).title()
    idx = indices[title]
    
    sim_scores = list(enumerate(cosine_sim[int(idx)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    
    movies = sdf.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year', 'id']]
    movies['est'] = movies['id'].apply(lambda x: model.predict(userId, indices_map.loc[x]['movieId']).est)
    movies = movies.sort_values('est', ascending=False)
    return movies.head(10)

# %%
hybrid_recommendations(100, 'the dark knight')
# Out:
#                            title  vote_count  vote_average  year      id  \
# 3373                     Memento      4168.0           8.1  2000      77
# 6587                The Prestige      4510.0           8.0  2006    1124
# 8573                Interstellar     11187.0           8.1  2014  157336
# 7608                   Inception     14075.0           8.1  2010   27205
# 6186               Batman Begins      7511.0           7.5  2005     272
# 7991       The Dark Knight Rises      9263.0           7.6  2012   49026
# 5907                    Thursday        84.0           7.0  1998    9812
# 7619  Batman: Under the Red Hood       459.0           7.6  2010   40662
# 2123                    Superman      1042.0           6.9  1978    1924
# 5773                 Point Blank        97.0           7.1  1967   26039
#
#            est
# 3373  4.155320
# 6587  4.037325
# 8573  4.033839
# 7608  4.012794
# 6186  3.699349
# 7991  3.564365
# 5907  3.463510
# 7619  3.298774
# 2123  3.291073
# 5773  3.242248
